# %% [markdown]
# # Titanic challenge with SageMaker - Remote Training

# %% [markdown]
# This notebook in in the series of learning SageMaker with Titanic challenge. The original challenge is defined at https://www.kaggle.com/c/titanic/data. In this notebook I experiment using SageMaker features from my local instead of using a SageMaker Notebook.
#
# In some cases, our local machines are strong enough to handle the data and we only want to use AWS resources for training and serving models. It can save costs of using Notebook Instances. The only difference to using a SageMaker Notebook Instance is that we must prepare a developing environment by ourselves and a proper credential to make requests to AWS from our local.
#
# Requirements:
# - Local environment with Python and necessary libraries/packages.
# - S3 buckets to store the data and the output
# - IAM user with the permission of writing to S3 and using SageMaker service.
# - An IAM role having permissions on S3 at least to be attached to training instances.
#
# This piece of code uses SageMaker 2.18.0 and XGBoost.

# %% [markdown]
# ## 1. Preparation

# %%
# import libraries
import boto3
import sagemaker

import pandas as pd
import numpy as np

# %%
# Define bucket name and prefix
bucket = '<bucket-name>' 
prefix = 'prefix'

# Define IAM role and sagemaker client
boto_session = boto3.Session()
session = sagemaker.Session(boto_session=boto_session)

# A role with the rights of reading and writing to S3
role = '<your:arn:role>'

# %%
# define the local data path
train_data_file = './data/processed/exp-raw/train.csv'
validation_data_file = './data/processed/exp-raw/validation.csv'
test_data_file = './data/processed/exp-raw/test.csv'

# %%
# upload local data into s3
s3_train_uri = session.upload_data(path=train_data_file, bucket=bucket, key_prefix='/'.join((prefix, 'basic/train')))
s3_validate_uri = session.upload_data(path=validation_data_file, bucket=bucket, key_prefix='/'.join((prefix, 'basic/validation')))
s3_test_uri = session.upload_data(path=test_data_file, bucket=bucket, key_prefix='/'.join((prefix, 'basic/test')))

# %% [markdown]
# ## 2. Model training

# %%
# Get the XGBoost image uri corresponding to the current region
from sagemaker import image_uris
container = image_uris.retrieve('xgboost', session.boto_region_name, 'latest')

# %%
# Define the estimator and hyperparams
xgb = sagemaker.estimator.Estimator(container,
                                    role, # role to be attached to instance to access data
                                    instance_count=1, 
                                    instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(bucket, prefix),
                                    use_spot_instances=True,
                                    max_run=400,
                                    max_wait=600)

xgb.set_hyperparameters(eval_metric='auc',
                        objective='binary:logistic',
                        num_round = 100,
                        early_stopping_round=10)

# %%
# Define the input points for xgboost
s3_input_train = sagemaker.inputs.TrainingInput(s3_data=s3_train_uri, content_type='csv')
s3_input_validation = sagemaker.inputs.TrainingInput(s3_data=s3_validate_uri, content_type='csv')

# %%
# Train the model
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2020-11-23 17:09:30 Starting - Starting the training job...
# 2020-11-23 17:09:32 Starting - Launching requested ML instances......
# 2020-11-23 17:10:39 Starting - Preparing the instances for training......
# 2020-11-23 17:11:39 Downloading - Downloading input data...
# 2020-11-23 17:12:31 Training - Training image download completed. Training in progress..Arguments: train
# [2020-11-23:17:12:32:INFO] Running standalone xgboost training.
# [2020-11-23:17:12:32:INFO] File size need to be processed in the node: 0.03mb. Available memory size in the node: 8474.34mb
# [2020-11-23:17:12:32:INFO] Determined delimiter of CSV input is ','
# [17:12:32] S3DistributionType set as FullyReplicated
# [17:12:32] 712x10 matrix with 7120 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-11-23:17:12:32:INFO] Determined delimiter of CSV input is ','
# [17:12:32] S3DistributionType set as FullyReplicated
# [17:12:32] 179x10 matrix with 1790 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [0]#011train-auc:0.897453#011validation-auc:0.853258
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-auc:0.904261#011validation-auc:0.844107
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [2]#011train-auc:0.917702#011validation-auc:0.863123
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [3]#011train-auc:0.932571#011validation-auc:0.869419
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [4]#011train-auc:0.943317#011validation-auc:0.875909
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-auc:0.949958#011validation-auc:0.880257
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [6]#011train-auc:0.956042#011validation-auc:0.874221
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [7]#011train-auc:0.960525#011validation-auc:0.869873
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [8]#011train-auc:0.964366#011validation-auc:0.862734
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [9]#011train-auc:0.968397#011validation-auc:0.861176
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [10]#011train-auc:0.971577#011validation-auc:0.858775
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [11]#011train-auc:0.975457#011validation-auc:0.858385
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [12]#011train-auc:0.977883#011validation-auc:0.856243
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [13]#011train-auc:0.978829#011validation-auc:0.856373
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [14]#011train-auc:0.981326#011validation-auc:0.858385
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [15]#011train-auc:0.98309#011validation-auc:0.860073
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [16]#011train-auc:0.984766#011validation-auc:0.857217
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [17]#011train-auc:0.987117#011validation-auc:0.853323
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [18]#011train-auc:0.988378#011validation-auc:0.851506
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [19]#011train-auc:0.989584#011validation-auc:0.852674
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [20]#011train-auc:0.990406#011validation-auc:0.852414
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [21]#011train-auc:0.991084#011validation-auc:0.846703
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [22]#011train-auc:0.992115#011validation-auc:0.845665
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [23]#011train-auc:0.993229#011validation-auc:0.845665
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [24]#011train-auc:0.994511#011validation-auc:0.845275
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [25]#011train-auc:0.995039#011validation-auc:0.848261
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [26]#011train-auc:0.995349#011validation-auc:0.844886
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [27]#011train-auc:0.995718#011validation-auc:0.847352
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [28]#011train-auc:0.996464#011validation-auc:0.848131
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [29]#011train-auc:0.996631#011validation-auc:0.851116
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [30]#011train-auc:0.997092#011validation-auc:0.847741
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [31]#011train-auc:0.997444#011validation-auc:0.84891
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [32]#011train-auc:0.997612#011validation-auc:0.849559
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [33]#011train-auc:0.998064#011validation-auc:0.846703
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [34]#011train-auc:0.998157#011validation-auc:0.844237
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [35]#011train-auc:0.998525#011validation-auc:0.843588
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [36]#011train-auc:0.998617#011validation-auc:0.843069
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [37]#011train-auc:0.998693#011validation-auc:0.842939
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [38]#011train-auc:0.99881#011validation-auc:0.841251
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [39]#011train-auc:0.998936#011validation-auc:0.839434
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [40]#011train-auc:0.999162#011validation-auc:0.840213
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [41]#011train-auc:0.999221#011validation-auc:0.839953
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [42]#011train-auc:0.999439#011validation-auc:0.838655
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [43]#011train-auc:0.999707#011validation-auc:0.835929
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [44]#011train-auc:0.99969#011validation-auc:0.83528
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [45]#011train-auc:0.99974#011validation-auc:0.834112
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [46]#011train-auc:0.999824#011validation-auc:0.83528
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=6
# [47]#011train-auc:0.999832#011validation-auc:0.833463
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [48]#011train-auc:0.99995#011validation-auc:0.835151
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [49]#011train-auc:0.999941#011validation-auc:0.834502
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [50]#011train-auc:0.99995#011validation-auc:0.835151
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [51]#011train-auc:0.999958#011validation-auc:0.83528
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [52]#011train-auc:0.999958#011validation-auc:0.836319
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=6
# [53]#011train-auc:0.999967#011validation-auc:0.833723
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [54]#011train-auc:0.999975#011validation-auc:0.833593
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [55]#011train-auc:0.999983#011validation-auc:0.834502
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [56]#011train-auc:0.999983#011validation-auc:0.8358
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [57]#011train-auc:0.999983#011validation-auc:0.8358
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [58]#011train-auc:1#011validation-auc:0.833593
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [59]#011train-auc:1#011validation-auc:0.834631
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [60]#011train-auc:0.999992#011validation-auc:0.832555
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [61]#011train-auc:0.999983#011validation-auc:0.833204
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [62]#011train-auc:0.999992#011validation-auc:0.834761
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [63]#011train-auc:1#011validation-auc:0.833074
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [64]#011train-auc:1#011validation-auc:0.834502
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=6
# [65]#011train-auc:1#011validation-auc:0.836449
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [66]#011train-auc:1#011validation-auc:0.835929
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [67]#011train-auc:1#011validation-auc:0.835021
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [68]#011train-auc:1#011validation-auc:0.834242
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [69]#011train-auc:1#011validation-auc:0.833333
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [70]#011train-auc:1#011validation-auc:0.833333
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [71]#011train-auc:1#011validation-auc:0.833463
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [72]#011train-auc:1#011validation-auc:0.833723
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [73]#011train-auc:1#011validation-auc:0.833074
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [74]#011train-auc:1#011validation-auc:0.83567
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [75]#011train-auc:1#011validation-auc:0.834761
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [76]#011train-auc:1#011validation-auc:0.836059
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [77]#011train-auc:1#011validation-auc:0.835151
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [78]#011train-auc:1#011validation-auc:0.834761
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [79]#011train-auc:1#011validation-auc:0.836449
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [80]#011train-auc:1#011validation-auc:0.837487
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [81]#011train-auc:1#011validation-auc:0.838655
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [82]#011train-auc:1#011validation-auc:0.837357
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [83]#011train-auc:1#011validation-auc:0.838655
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [84]#011train-auc:1#011validation-auc:0.836708
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [85]#011train-auc:1#011validation-auc:0.837617
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [86]#011train-auc:1#011validation-auc:0.838136
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [87]#011train-auc:1#011validation-auc:0.838266
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [88]#011train-auc:1#011validation-auc:0.839174
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [89]#011train-auc:1#011validation-auc:0.839045
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [90]#011train-auc:1#011validation-auc:0.839304
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [91]#011train-auc:1#011validation-auc:0.840083
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [92]#011train-auc:1#011validation-auc:0.839953
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [93]#011train-auc:1#011validation-auc:0.839304
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [94]#011train-auc:1#011validation-auc:0.839304
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [95]#011train-auc:1#011validation-auc:0.840732
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [96]#011train-auc:1#011validation-auc:0.839823
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [97]#011train-auc:1#011validation-auc:0.839045
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [98]#011train-auc:1#011validation-auc:0.837747
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [99]#011train-auc:1#011validation-auc:0.838266
# 2020-11-23 17:12:44 Uploading - Uploading generated training model
# 2020-11-23 17:12:44 Completed - Training job completed
# Training seconds: 65
# Billable seconds: 24
# Managed Spot Training savings: 63.1%

# %% [markdown]
# ## 3. Make predictions

# %%
# Deploy the estimator with Batch Transform 
xgb_transformer = xgb.transformer(instance_count=1,
                                  instance_type='ml.m4.xlarge',
                                  strategy='MultiRecord',
                                  assemble_with='Line',
                                  output_path='s3://{}/{}/prediction/'.format(bucket, prefix))

# %%
xgb_transformer.transform(s3_test_uri, content_type='text/csv', split_type='Line')
xgb_transformer.wait()
# Out:
# Wall time: 0 ns
# ............................2020-11-23T17:20:53.026:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# Arguments: serve
# [2020-11-23 17:20:52 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2020-11-23 17:20:52 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2020-11-23 17:20:52 +0000] [1] [INFO] Using worker: gevent
# Arguments: serve
# [2020-11-23 17:20:52 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2020-11-23 17:20:52 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2020-11-23 17:20:52 +0000] [1] [INFO] Using worker: gevent
# [2020-11-23 17:20:52 +0000] [36] [INFO] Booting worker with pid: 36
# [2020-11-23 17:20:52 +0000] [37] [INFO] Booting worker with pid: 37
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 36
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 37
# [2020-11-23 17:20:53 +0000] [38] [INFO] Booting worker with pid: 38
# [2020-11-23 17:20:53 +0000] [39] [INFO] Booting worker with pid: 39
# [2020-11-23:17:20:53:INFO] Sniff delimiter as ','
# [2020-11-23:17:20:53:INFO] Determined delimiter of CSV input is ','
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 38
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 39
# [2020-11-23 17:20:52 +0000] [36] [INFO] Booting worker with pid: 36
# [2020-11-23 17:20:52 +0000] [37] [INFO] Booting worker with pid: 37
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 36
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 37
# [2020-11-23 17:20:53 +0000] [38] [INFO] Booting worker with pid: 38
# [2020-11-23 17:20:53 +0000] [39] [INFO] Booting worker with pid: 39
# [2020-11-23:17:20:53:INFO] Sniff delimiter as ','
# [2020-11-23:17:20:53:INFO] Determined delimiter of CSV input is ','
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 38
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 39
#
# 2020-11-23T17:20:53.026:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# Arguments: serve
# [2020-11-23 17:20:52 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2020-11-23 17:20:52 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2020-11-23 17:20:52 +0000] [1] [INFO] Using worker: gevent
# Arguments: serve
# [2020-11-23 17:20:52 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2020-11-23 17:20:52 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2020-11-23 17:20:52 +0000] [1] [INFO] Using worker: gevent
# [2020-11-23 17:20:52 +0000] [36] [INFO] Booting worker with pid: 36
# [2020-11-23 17:20:52 +0000] [37] [INFO] Booting worker with pid: 37
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 36
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 37
# [2020-11-23 17:20:53 +0000] [38] [INFO] Booting worker with pid: 38
# [2020-11-23 17:20:53 +0000] [39] [INFO] Booting worker with pid: 39
# [2020-11-23:17:20:53:INFO] Sniff delimiter as ','
# [2020-11-23:17:20:53:INFO] Determined delimiter of CSV input is ','
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 38
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 39
# [2020-11-23 17:20:52 +0000] [36] [INFO] Booting worker with pid: 36
# [2020-11-23 17:20:52 +0000] [37] [INFO] Booting worker with pid: 37
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 36
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 37
# [2020-11-23 17:20:53 +0000] [38] [INFO] Booting worker with pid: 38
# [2020-11-23 17:20:53 +0000] [39] [INFO] Booting worker with pid: 39
# [2020-11-23:17:20:53:INFO] Sniff delimiter as ','
# [2020-11-23:17:20:53:INFO] Determined delimiter of CSV input is ','
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 38
# [2020-11-23:17:20:53:INFO] Model loaded successfully for worker : 39

# %%
result_df = pd.read_csv('s3://{}/{}/prediction/test.csv.out'.format(bucket, prefix),header=None,names=['Survived'])

# %%
result_df.head(5)
# Out:
#    Survived
# 0  0.001603
# 1  0.067456
# 2  0.005251
# 3  0.010396
# 4  0.260264
